# %%
import os
from pathlib import Path
import pandas as pd

# %%
data_path = Path(os.environ["DATA_PATH"])

# %%
df = pd.read_excel(data_path / "processing" / "2" / "Analytics - RPPC - Interés Social - 2020 a 2025.xlsx").drop(columns=["#"])

# %%
df.loc[lambda df: df["Fraccionamiento"] == "VILLA FLORIDA"]
# Out:
#        Folio real Fecha de operación Municipio Mercado (UMAs) Fraccionamiento  \
# 261      161920.0         2025-11-20  MEXICALI            VIS   VILLA FLORIDA
# 272      163174.0         2025-11-19  MEXICALI            VIS   VILLA FLORIDA
# 390      161691.0         2025-10-31  MEXICALI            VIS   VILLA FLORIDA
# 556      145785.0         2025-10-17  MEXICALI            VIS   VILLA FLORIDA
# 841      157259.0         2025-09-10  MEXICALI            VIS   VILLA FLORIDA
# ...           ...                ...       ...            ...             ...
# 27825    145928.0         2020-03-02  MEXICALI            VIS   VILLA FLORIDA
# 27827    173575.0         2020-03-02  MEXICALI            VIS   VILLA FLORIDA
# 28471    145867.0         2020-01-24  MEXICALI            VIS   VILLA FLORIDA
# 28650    163459.0         2020-01-07  MEXICALI            VIS   VILLA FLORIDA
# 28653    157251.0         2020-01-06  MEXICALI            VIS   VILLA FLORIDA
#
# ...

# %%
df["Fraccionamiento"].value_counts()
# Out:
# Fraccionamiento
# LA CONDESA                          5303
# PARAJES DE PUEBLA                   1863
# VALLE DE PUEBLA                     1808
# ANGELES DE PUEBLA                   1096
# HACIENDA DE LOS PORTALES             892
#                                     ...
# ZONA URBANA DEL EJIDO XOCHIMILCO       1
# HECHICERA                              1
# LA ESCONDIDA                           1
# PAREDONES                              1
# REAL DEL SOL                           1
# Name: count, Length: 526, dtype: int64
